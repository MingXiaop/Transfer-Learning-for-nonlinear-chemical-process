# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, SimpleRNN, Input, Activation, Dropout
from keras import backend as K
from tensorflow.keras.optimizers import Adam,SGD
import tensorflow as tf
from keras.models import Model
from keras.models import load_model
import time #to calculate the computation time
# Out:
# 2022-10-13 01:27:34.581283: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-13 01:27:34.581316: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Generate data from first-principles model

# %%
# specifying constant parameters
#input varioable: Q, C_A0
#state variable: T, C_A

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314



T_0 += 0.1 * T_0
V += 0.1 * V
k_0 += 0.1 * k_0
C_p += 0.1 * C_p
rho_L += 0.1 * rho_L
F += 0.1 * F
E += 0.1 * E
delta_H += 0.1 * delta_H
R = R    #constant
  
Q_s = 0.0  # the steady state for input variable Q
C_A0s = 4.2   # the steady state for input variable C_A0

#calculated by let dCA/dt,dT/dt =0, via scipy
T_s = 333.47  #151997  # the steady state for state variable T
C_As = 4.12  #32945  # the steady state for state variable C_A

t_final = 0.01  #the control period
t_step = 1e-4   # the step to use first-principle to calculate the state
P = np.array([[1060, 22], [22, 0.52]])

# %%
#The data size for new-cstr should be consensus with the basic-one
# generating inputs and initial states for CSTR, all expressed in deviation form

# Test 1 full stability region
u1_list = np.linspace(-3.5, 3.5, 30, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 30, endpoint=True)
T_initial = np.linspace(200, 550, 30, endpoint=True) - T_s
CA_initial = np.linspace(0, 8., 30, endpoint=True) - C_As
#print(T_initial)
#control variable: C_A0, Q
#state variable: C_A, T

# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:   
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 480:   #calculate the stability region for state 
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
print(CA_start.shape)
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
print(x_deviation.shape)  # the initial state is in
# Out:
# number of initial conditions: 56
# (1, 56)
# shape of x_deviation is (56, 2)
# (56, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """
    
    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time
    
    C_A = C_A_initial + C_As  # the real state.the derivation plus the steady state
    T = T_initial + T_s
    
    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)
        
        C_A += dCAdt * t_step
        T += dTdt * t_step
        
        if i%5 ==0:
            C_A_list.append(C_A - C_As)  # in deviation form
            T_list.append(T - T_s)  # in deviation form 
    
    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()

CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()   #input variable for 

for u1 in u1_list:
    C_A0 = u1 + C_A0s
    
    for u2 in u2_list:
        Q = u2 + Q_s
        
        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)
            
            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input), axis=2)   #the value for input variable and the initial value for state variable 

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""
print("RNN_input shape is {}".format(RNN_input.shape))
RNN_input = RNN_input.repeat(20, axis=1)  # to keep consensus with the shape for RNN_output, since the output variable is collected 100(0.01/1e-4) times for each RNN_input
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (50400, 1, 4)
# RNN_input shape is (50400, 20, 4)

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, 20, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, 20, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (50400, 20, 2)

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.15, random_state=123)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.StandardScaler().fit(X_train.reshape(-1, 4))
scaler_y = preprocessing.StandardScaler().fit(y_train.reshape(-1, 2))


X_train = scaler_X.transform(X_train.reshape(-1, 4)).reshape(-1,20,4)
X_test = scaler_X.transform(X_test.reshape(-1, 4)).reshape(-1,20,4)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,20,2)
y_test = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,20,2)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (42840, 20, 4) (7560, 20, 4) (42840, 20, 2) (7560, 20, 2)

# %% [markdown]
# # Develop the pre-trained model with sufficient source data

# %%
model1 = Sequential()
model1.add(SimpleRNN(32, activation='tanh', return_sequences=True))
model1.add(Dense(2, activation='linear'))
model1.compile(optimizer='adam', loss='mse', metrics=['mse'])

t0 = time.time()
history = model1.fit(X_train, y_train, epochs=150, batch_size=256, validation_split=0.25, verbose=2)
t1 = time.time()
# Out:
# Epoch 1/150
# 2022-10-13 01:28:10.889429: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-10-13 01:28:10.889490: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-13 01:28:10.889513: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c895b2a47570): /proc/driver/nvidia/version does not exist
# 2022-10-13 01:28:10.889753: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 126/126 - 1s - loss: 0.1560 - mse: 0.1560 - val_loss: 0.0293 - val_mse: 0.0293 - 1s/epoch - 11ms/step
# Epoch 2/150
# 126/126 - 1s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0122 - val_mse: 0.0122 - 655ms/epoch - 5ms/step
# Epoch 3/150
# 126/126 - 1s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0067 - val_mse: 0.0067 - 716ms/epoch - 6ms/step
# Epoch 4/150
# 126/126 - 1s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0046 - val_mse: 0.0046 - 726ms/epoch - 6ms/step
# Epoch 5/150
# 126/126 - 1s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 776ms/epoch - 6ms/step
# Epoch 6/150
# 126/126 - 1s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0030 - val_mse: 0.0030 - 761ms/epoch - 6ms/step
# Epoch 7/150
# 126/126 - 1s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0025 - val_mse: 0.0025 - 667ms/epoch - 5ms/step
# Epoch 8/150
# 126/126 - 1s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0022 - val_mse: 0.0022 - 701ms/epoch - 6ms/step
# Epoch 9/150
# 126/126 - 1s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019 - 708ms/epoch - 6ms/step
# Epoch 10/150
# 126/126 - 1s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 820ms/epoch - 7ms/step
# Epoch 11/150
# 126/126 - 1s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 739ms/epoch - 6ms/step
# Epoch 12/150
# 126/126 - 1s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 726ms/epoch - 6ms/step
# Epoch 13/150
# 126/126 - 1s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 768ms/epoch - 6ms/step
# Epoch 14/150
# 126/126 - 1s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 810ms/epoch - 6ms/step
# Epoch 15/150
# 126/126 - 1s - loss: 9.3415e-04 - mse: 9.3415e-04 - val_loss: 9.0565e-04 - val_mse: 9.0565e-04 - 698ms/epoch - 6ms/step
# Epoch 16/150
# 126/126 - 1s - loss: 8.4327e-04 - mse: 8.4327e-04 - val_loss: 8.2145e-04 - val_mse: 8.2145e-04 - 735ms/epoch - 6ms/step
# Epoch 17/150
# 126/126 - 1s - loss: 7.7089e-04 - mse: 7.7089e-04 - val_loss: 7.5272e-04 - val_mse: 7.5272e-04 - 778ms/epoch - 6ms/step
# Epoch 18/150
# 126/126 - 1s - loss: 7.0355e-04 - mse: 7.0355e-04 - val_loss: 6.9949e-04 - val_mse: 6.9949e-04 - 739ms/epoch - 6ms/step
# Epoch 19/150
# 126/126 - 1s - loss: 6.4583e-04 - mse: 6.4583e-04 - val_loss: 6.3103e-04 - val_mse: 6.3103e-04 - 701ms/epoch - 6ms/step
# Epoch 20/150
# 126/126 - 1s - loss: 5.9436e-04 - mse: 5.9436e-04 - val_loss: 5.8724e-04 - val_mse: 5.8724e-04 - 680ms/epoch - 5ms/step
# Epoch 21/150
# 126/126 - 1s - loss: 5.4922e-04 - mse: 5.4922e-04 - val_loss: 5.3593e-04 - val_mse: 5.3593e-04 - 716ms/epoch - 6ms/step
# Epoch 22/150
# 126/126 - 1s - loss: 5.0343e-04 - mse: 5.0343e-04 - val_loss: 4.9382e-04 - val_mse: 4.9382e-04 - 694ms/epoch - 6ms/step
# Epoch 23/150
# 126/126 - 1s - loss: 4.6863e-04 - mse: 4.6863e-04 - val_loss: 4.5554e-04 - val_mse: 4.5554e-04 - 747ms/epoch - 6ms/step
# Epoch 24/150
# 126/126 - 1s - loss: 4.3483e-04 - mse: 4.3483e-04 - val_loss: 4.3520e-04 - val_mse: 4.3520e-04 - 867ms/epoch - 7ms/step
# Epoch 25/150
# 126/126 - 1s - loss: 4.0597e-04 - mse: 4.0597e-04 - val_loss: 4.0169e-04 - val_mse: 4.0169e-04 - 776ms/epoch - 6ms/step
# Epoch 26/150
# 126/126 - 1s - loss: 3.8217e-04 - mse: 3.8217e-04 - val_loss: 3.9439e-04 - val_mse: 3.9439e-04 - 684ms/epoch - 5ms/step
# Epoch 27/150
# 126/126 - 1s - loss: 3.5610e-04 - mse: 3.5610e-04 - val_loss: 3.4838e-04 - val_mse: 3.4838e-04 - 677ms/epoch - 5ms/step
# Epoch 28/150
# 126/126 - 1s - loss: 3.3192e-04 - mse: 3.3192e-04 - val_loss: 3.3989e-04 - val_mse: 3.3989e-04 - 790ms/epoch - 6ms/step
# Epoch 29/150
# 126/126 - 1s - loss: 3.2219e-04 - mse: 3.2219e-04 - val_loss: 3.4228e-04 - val_mse: 3.4228e-04 - 661ms/epoch - 5ms/step
# Epoch 30/150
# 126/126 - 1s - loss: 2.9132e-04 - mse: 2.9132e-04 - val_loss: 3.0058e-04 - val_mse: 3.0058e-04 - 796ms/epoch - 6ms/step
# Epoch 31/150
# 126/126 - 1s - loss: 2.7957e-04 - mse: 2.7957e-04 - val_loss: 3.0594e-04 - val_mse: 3.0594e-04 - 854ms/epoch - 7ms/step
# Epoch 32/150
# 126/126 - 1s - loss: 2.6904e-04 - mse: 2.6904e-04 - val_loss: 2.6943e-04 - val_mse: 2.6943e-04 - 717ms/epoch - 6ms/step
# Epoch 33/150
# 126/126 - 1s - loss: 2.4565e-04 - mse: 2.4565e-04 - val_loss: 2.4802e-04 - val_mse: 2.4802e-04 - 699ms/epoch - 6ms/step
# Epoch 34/150
# 126/126 - 1s - loss: 2.2727e-04 - mse: 2.2727e-04 - val_loss: 2.2516e-04 - val_mse: 2.2516e-04 - 720ms/epoch - 6ms/step
# Epoch 35/150
# 126/126 - 1s - loss: 2.3420e-04 - mse: 2.3420e-04 - val_loss: 2.1965e-04 - val_mse: 2.1965e-04 - 748ms/epoch - 6ms/step
# Epoch 36/150
# 126/126 - 1s - loss: 2.2055e-04 - mse: 2.2055e-04 - val_loss: 2.2009e-04 - val_mse: 2.2009e-04 - 637ms/epoch - 5ms/step
# Epoch 37/150
# 126/126 - 1s - loss: 1.9633e-04 - mse: 1.9633e-04 - val_loss: 1.8798e-04 - val_mse: 1.8798e-04 - 726ms/epoch - 6ms/step
# Epoch 38/150
# 126/126 - 1s - loss: 1.9972e-04 - mse: 1.9972e-04 - val_loss: 2.3594e-04 - val_mse: 2.3594e-04 - 765ms/epoch - 6ms/step
# Epoch 39/150
# 126/126 - 1s - loss: 1.7976e-04 - mse: 1.7976e-04 - val_loss: 1.7850e-04 - val_mse: 1.7850e-04 - 706ms/epoch - 6ms/step
# Epoch 40/150
# 126/126 - 1s - loss: 1.8001e-04 - mse: 1.8001e-04 - val_loss: 1.7018e-04 - val_mse: 1.7018e-04 - 707ms/epoch - 6ms/step
# Epoch 41/150
# 126/126 - 1s - loss: 1.7528e-04 - mse: 1.7528e-04 - val_loss: 1.8118e-04 - val_mse: 1.8118e-04 - 678ms/epoch - 5ms/step
# Epoch 42/150
# 126/126 - 1s - loss: 1.7065e-04 - mse: 1.7065e-04 - val_loss: 1.7639e-04 - val_mse: 1.7639e-04 - 700ms/epoch - 6ms/step
# Epoch 43/150
# 126/126 - 1s - loss: 1.5315e-04 - mse: 1.5315e-04 - val_loss: 1.7701e-04 - val_mse: 1.7701e-04 - 659ms/epoch - 5ms/step
# Epoch 44/150
# 126/126 - 1s - loss: 1.4918e-04 - mse: 1.4918e-04 - val_loss: 1.4106e-04 - val_mse: 1.4106e-04 - 697ms/epoch - 6ms/step
# Epoch 45/150
# 126/126 - 1s - loss: 1.5174e-04 - mse: 1.5174e-04 - val_loss: 1.4025e-04 - val_mse: 1.4025e-04 - 730ms/epoch - 6ms/step
# Epoch 46/150
# 126/126 - 1s - loss: 1.4295e-04 - mse: 1.4295e-04 - val_loss: 1.3829e-04 - val_mse: 1.3829e-04 - 712ms/epoch - 6ms/step
# Epoch 47/150
# 126/126 - 1s - loss: 1.2930e-04 - mse: 1.2930e-04 - val_loss: 1.2225e-04 - val_mse: 1.2225e-04 - 668ms/epoch - 5ms/step
# Epoch 48/150
# 126/126 - 1s - loss: 1.2608e-04 - mse: 1.2608e-04 - val_loss: 1.2871e-04 - val_mse: 1.2871e-04 - 678ms/epoch - 5ms/step
# Epoch 49/150
# 126/126 - 1s - loss: 1.2246e-04 - mse: 1.2246e-04 - val_loss: 1.5095e-04 - val_mse: 1.5095e-04 - 752ms/epoch - 6ms/step
# Epoch 50/150
# 126/126 - 1s - loss: 1.2168e-04 - mse: 1.2168e-04 - val_loss: 1.2482e-04 - val_mse: 1.2482e-04 - 673ms/epoch - 5ms/step
# Epoch 51/150
# 126/126 - 1s - loss: 1.1585e-04 - mse: 1.1585e-04 - val_loss: 1.1737e-04 - val_mse: 1.1737e-04 - 726ms/epoch - 6ms/step
# Epoch 52/150
# 126/126 - 1s - loss: 1.1903e-04 - mse: 1.1903e-04 - val_loss: 1.0673e-04 - val_mse: 1.0673e-04 - 654ms/epoch - 5ms/step
# Epoch 53/150
# 126/126 - 1s - loss: 1.0338e-04 - mse: 1.0338e-04 - val_loss: 1.0500e-04 - val_mse: 1.0500e-04 - 677ms/epoch - 5ms/step
# Epoch 54/150
# 126/126 - 1s - loss: 1.0684e-04 - mse: 1.0684e-04 - val_loss: 9.9314e-05 - val_mse: 9.9314e-05 - 664ms/epoch - 5ms/step
# Epoch 55/150
# 126/126 - 1s - loss: 1.1590e-04 - mse: 1.1590e-04 - val_loss: 1.1427e-04 - val_mse: 1.1427e-04 - 653ms/epoch - 5ms/step
# Epoch 56/150
# 126/126 - 1s - loss: 9.6747e-05 - mse: 9.6747e-05 - val_loss: 1.1883e-04 - val_mse: 1.1883e-04 - 670ms/epoch - 5ms/step
# Epoch 57/150
# 126/126 - 1s - loss: 9.3011e-05 - mse: 9.3011e-05 - val_loss: 9.2859e-05 - val_mse: 9.2859e-05 - 662ms/epoch - 5ms/step
# Epoch 58/150
# 126/126 - 1s - loss: 9.6905e-05 - mse: 9.6905e-05 - val_loss: 9.1172e-05 - val_mse: 9.1172e-05 - 773ms/epoch - 6ms/step
# Epoch 59/150
# 126/126 - 1s - loss: 8.1928e-05 - mse: 8.1928e-05 - val_loss: 8.0383e-05 - val_mse: 8.0383e-05 - 839ms/epoch - 7ms/step
# Epoch 60/150
# 126/126 - 1s - loss: 9.3621e-05 - mse: 9.3621e-05 - val_loss: 9.4912e-05 - val_mse: 9.4912e-05 - 759ms/epoch - 6ms/step
# Epoch 61/150
# 126/126 - 1s - loss: 9.1961e-05 - mse: 9.1961e-05 - val_loss: 9.3559e-05 - val_mse: 9.3559e-05 - 765ms/epoch - 6ms/step
# Epoch 62/150
# 126/126 - 1s - loss: 8.4758e-05 - mse: 8.4758e-05 - val_loss: 8.4932e-05 - val_mse: 8.4932e-05 - 857ms/epoch - 7ms/step
# Epoch 63/150
# 126/126 - 1s - loss: 9.0434e-05 - mse: 9.0434e-05 - val_loss: 1.3040e-04 - val_mse: 1.3040e-04 - 777ms/epoch - 6ms/step
# Epoch 64/150
# 126/126 - 1s - loss: 8.2081e-05 - mse: 8.2081e-05 - val_loss: 1.2015e-04 - val_mse: 1.2015e-04 - 685ms/epoch - 5ms/step
# Epoch 65/150
# 126/126 - 1s - loss: 7.6909e-05 - mse: 7.6909e-05 - val_loss: 8.5621e-05 - val_mse: 8.5621e-05 - 754ms/epoch - 6ms/step
# Epoch 66/150
# 126/126 - 1s - loss: 7.7326e-05 - mse: 7.7326e-05 - val_loss: 6.4048e-05 - val_mse: 6.4048e-05 - 665ms/epoch - 5ms/step
# Epoch 67/150
# 126/126 - 1s - loss: 7.2934e-05 - mse: 7.2934e-05 - val_loss: 7.0573e-05 - val_mse: 7.0573e-05 - 688ms/epoch - 5ms/step
# Epoch 68/150
# 126/126 - 1s - loss: 8.0724e-05 - mse: 8.0724e-05 - val_loss: 8.2789e-05 - val_mse: 8.2789e-05 - 645ms/epoch - 5ms/step
# Epoch 69/150
# 126/126 - 1s - loss: 7.5601e-05 - mse: 7.5601e-05 - val_loss: 6.4493e-05 - val_mse: 6.4493e-05 - 750ms/epoch - 6ms/step
# Epoch 70/150
# 126/126 - 1s - loss: 6.7396e-05 - mse: 6.7396e-05 - val_loss: 6.2849e-05 - val_mse: 6.2849e-05 - 760ms/epoch - 6ms/step
# Epoch 71/150
# 126/126 - 1s - loss: 7.2674e-05 - mse: 7.2674e-05 - val_loss: 5.7893e-05 - val_mse: 5.7893e-05 - 700ms/epoch - 6ms/step
# Epoch 72/150
# 126/126 - 1s - loss: 6.6790e-05 - mse: 6.6790e-05 - val_loss: 5.7299e-05 - val_mse: 5.7299e-05 - 849ms/epoch - 7ms/step
# Epoch 73/150
# 126/126 - 1s - loss: 7.9238e-05 - mse: 7.9238e-05 - val_loss: 7.1191e-05 - val_mse: 7.1191e-05 - 844ms/epoch - 7ms/step
# Epoch 74/150
# 126/126 - 1s - loss: 5.9723e-05 - mse: 5.9723e-05 - val_loss: 5.7082e-05 - val_mse: 5.7082e-05 - 902ms/epoch - 7ms/step
# Epoch 75/150
# 126/126 - 1s - loss: 6.4325e-05 - mse: 6.4325e-05 - val_loss: 7.0066e-05 - val_mse: 7.0066e-05 - 820ms/epoch - 7ms/step
# Epoch 76/150
# 126/126 - 1s - loss: 6.8265e-05 - mse: 6.8265e-05 - val_loss: 7.8323e-05 - val_mse: 7.8323e-05 - 749ms/epoch - 6ms/step
# Epoch 77/150
# 126/126 - 1s - loss: 5.7458e-05 - mse: 5.7458e-05 - val_loss: 6.6108e-05 - val_mse: 6.6108e-05 - 754ms/epoch - 6ms/step
# Epoch 78/150
# 126/126 - 1s - loss: 6.5419e-05 - mse: 6.5419e-05 - val_loss: 5.5603e-05 - val_mse: 5.5603e-05 - 889ms/epoch - 7ms/step
# Epoch 79/150
# 126/126 - 1s - loss: 5.5617e-05 - mse: 5.5617e-05 - val_loss: 4.6696e-05 - val_mse: 4.6696e-05 - 747ms/epoch - 6ms/step
# Epoch 80/150
# 126/126 - 1s - loss: 5.4802e-05 - mse: 5.4802e-05 - val_loss: 6.6233e-05 - val_mse: 6.6233e-05 - 822ms/epoch - 7ms/step
# Epoch 81/150
# 126/126 - 1s - loss: 6.3694e-05 - mse: 6.3694e-05 - val_loss: 4.6978e-05 - val_mse: 4.6978e-05 - 773ms/epoch - 6ms/step
# Epoch 82/150
# 126/126 - 1s - loss: 5.3816e-05 - mse: 5.3816e-05 - val_loss: 7.7568e-05 - val_mse: 7.7568e-05 - 780ms/epoch - 6ms/step
# Epoch 83/150
# 126/126 - 1s - loss: 5.3997e-05 - mse: 5.3997e-05 - val_loss: 4.9341e-05 - val_mse: 4.9341e-05 - 805ms/epoch - 6ms/step
# Epoch 84/150
# 126/126 - 1s - loss: 6.2729e-05 - mse: 6.2729e-05 - val_loss: 5.3294e-05 - val_mse: 5.3294e-05 - 729ms/epoch - 6ms/step
# Epoch 85/150
# 126/126 - 1s - loss: 5.1952e-05 - mse: 5.1952e-05 - val_loss: 5.0976e-05 - val_mse: 5.0976e-05 - 754ms/epoch - 6ms/step
# Epoch 86/150
# 126/126 - 1s - loss: 5.2498e-05 - mse: 5.2498e-05 - val_loss: 7.7799e-05 - val_mse: 7.7799e-05 - 790ms/epoch - 6ms/step
# Epoch 87/150
# 126/126 - 1s - loss: 5.1361e-05 - mse: 5.1361e-05 - val_loss: 4.7466e-05 - val_mse: 4.7466e-05 - 752ms/epoch - 6ms/step
# Epoch 88/150
# 126/126 - 1s - loss: 5.5257e-05 - mse: 5.5257e-05 - val_loss: 4.7552e-05 - val_mse: 4.7552e-05 - 745ms/epoch - 6ms/step
# Epoch 89/150
# 126/126 - 1s - loss: 5.0635e-05 - mse: 5.0635e-05 - val_loss: 9.5708e-05 - val_mse: 9.5708e-05 - 692ms/epoch - 5ms/step
# Epoch 90/150
# 126/126 - 1s - loss: 4.9459e-05 - mse: 4.9459e-05 - val_loss: 4.1377e-05 - val_mse: 4.1377e-05 - 656ms/epoch - 5ms/step
# Epoch 91/150
# 126/126 - 1s - loss: 5.0512e-05 - mse: 5.0512e-05 - val_loss: 8.6250e-05 - val_mse: 8.6250e-05 - 896ms/epoch - 7ms/step
# Epoch 92/150
# 126/126 - 1s - loss: 4.9243e-05 - mse: 4.9243e-05 - val_loss: 5.2747e-05 - val_mse: 5.2747e-05 - 667ms/epoch - 5ms/step
# Epoch 93/150
# 126/126 - 1s - loss: 4.7948e-05 - mse: 4.7948e-05 - val_loss: 3.8964e-05 - val_mse: 3.8964e-05 - 724ms/epoch - 6ms/step
# Epoch 94/150
# 126/126 - 1s - loss: 4.6394e-05 - mse: 4.6394e-05 - val_loss: 4.5704e-05 - val_mse: 4.5704e-05 - 668ms/epoch - 5ms/step
# Epoch 95/150
# 126/126 - 1s - loss: 4.4546e-05 - mse: 4.4546e-05 - val_loss: 3.9826e-05 - val_mse: 3.9826e-05 - 668ms/epoch - 5ms/step
# Epoch 96/150
# 126/126 - 1s - loss: 4.1495e-05 - mse: 4.1495e-05 - val_loss: 5.0395e-05 - val_mse: 5.0395e-05 - 672ms/epoch - 5ms/step
# Epoch 97/150
# 126/126 - 1s - loss: 4.9830e-05 - mse: 4.9830e-05 - val_loss: 4.5035e-05 - val_mse: 4.5035e-05 - 726ms/epoch - 6ms/step
# Epoch 98/150
# 126/126 - 1s - loss: 4.6666e-05 - mse: 4.6666e-05 - val_loss: 3.7143e-05 - val_mse: 3.7143e-05 - 814ms/epoch - 6ms/step
# Epoch 99/150
# 126/126 - 1s - loss: 4.5124e-05 - mse: 4.5124e-05 - val_loss: 3.9352e-05 - val_mse: 3.9352e-05 - 687ms/epoch - 5ms/step
# Epoch 100/150
# 126/126 - 1s - loss: 4.1965e-05 - mse: 4.1965e-05 - val_loss: 3.7078e-05 - val_mse: 3.7078e-05 - 963ms/epoch - 8ms/step
# Epoch 101/150
# 126/126 - 1s - loss: 4.4761e-05 - mse: 4.4761e-05 - val_loss: 3.2525e-05 - val_mse: 3.2525e-05 - 835ms/epoch - 7ms/step
# Epoch 102/150
# 126/126 - 1s - loss: 4.3725e-05 - mse: 4.3725e-05 - val_loss: 3.4366e-05 - val_mse: 3.4366e-05 - 791ms/epoch - 6ms/step
# Epoch 103/150
# 126/126 - 1s - loss: 4.4299e-05 - mse: 4.4299e-05 - val_loss: 3.3650e-05 - val_mse: 3.3650e-05 - 810ms/epoch - 6ms/step
# Epoch 104/150
# 126/126 - 1s - loss: 3.7542e-05 - mse: 3.7542e-05 - val_loss: 5.0941e-05 - val_mse: 5.0941e-05 - 909ms/epoch - 7ms/step
# Epoch 105/150
# 126/126 - 1s - loss: 4.5345e-05 - mse: 4.5345e-05 - val_loss: 3.1626e-05 - val_mse: 3.1626e-05 - 767ms/epoch - 6ms/step
# Epoch 106/150
# 126/126 - 1s - loss: 3.7207e-05 - mse: 3.7207e-05 - val_loss: 2.9514e-05 - val_mse: 2.9514e-05 - 819ms/epoch - 6ms/step
# Epoch 107/150
# 126/126 - 1s - loss: 3.7045e-05 - mse: 3.7045e-05 - val_loss: 5.3462e-05 - val_mse: 5.3462e-05 - 724ms/epoch - 6ms/step
# Epoch 108/150
# 126/126 - 1s - loss: 4.9280e-05 - mse: 4.9280e-05 - val_loss: 8.3165e-05 - val_mse: 8.3165e-05 - 807ms/epoch - 6ms/step
# Epoch 109/150
# 126/126 - 1s - loss: 3.8954e-05 - mse: 3.8954e-05 - val_loss: 4.6888e-05 - val_mse: 4.6888e-05 - 789ms/epoch - 6ms/step
# Epoch 110/150
# 126/126 - 1s - loss: 3.6224e-05 - mse: 3.6224e-05 - val_loss: 3.3423e-05 - val_mse: 3.3423e-05 - 787ms/epoch - 6ms/step
# Epoch 111/150
# 126/126 - 1s - loss: 3.7503e-05 - mse: 3.7503e-05 - val_loss: 5.4496e-05 - val_mse: 5.4496e-05 - 801ms/epoch - 6ms/step
# Epoch 112/150
# 126/126 - 1s - loss: 3.9656e-05 - mse: 3.9656e-05 - val_loss: 3.3313e-05 - val_mse: 3.3313e-05 - 950ms/epoch - 8ms/step
# Epoch 113/150
# 126/126 - 1s - loss: 3.7331e-05 - mse: 3.7331e-05 - val_loss: 4.6025e-05 - val_mse: 4.6025e-05 - 710ms/epoch - 6ms/step
# Epoch 114/150
# 126/126 - 1s - loss: 4.3353e-05 - mse: 4.3353e-05 - val_loss: 3.3160e-05 - val_mse: 3.3160e-05 - 719ms/epoch - 6ms/step
# Epoch 115/150
# 126/126 - 1s - loss: 3.0752e-05 - mse: 3.0752e-05 - val_loss: 2.7135e-05 - val_mse: 2.7135e-05 - 684ms/epoch - 5ms/step
# Epoch 116/150
# 126/126 - 1s - loss: 3.3632e-05 - mse: 3.3632e-05 - val_loss: 3.6704e-05 - val_mse: 3.6704e-05 - 763ms/epoch - 6ms/step
# Epoch 117/150
# 126/126 - 1s - loss: 4.3623e-05 - mse: 4.3623e-05 - val_loss: 4.2519e-05 - val_mse: 4.2519e-05 - 756ms/epoch - 6ms/step
# Epoch 118/150
# 126/126 - 1s - loss: 3.4887e-05 - mse: 3.4887e-05 - val_loss: 2.6946e-05 - val_mse: 2.6946e-05 - 664ms/epoch - 5ms/step
# Epoch 119/150
# 126/126 - 1s - loss: 3.6408e-05 - mse: 3.6408e-05 - val_loss: 4.4049e-05 - val_mse: 4.4049e-05 - 685ms/epoch - 5ms/step
# Epoch 120/150
# 126/126 - 1s - loss: 3.0752e-05 - mse: 3.0752e-05 - val_loss: 5.1613e-05 - val_mse: 5.1613e-05 - 647ms/epoch - 5ms/step
# Epoch 121/150
# 126/126 - 1s - loss: 3.9380e-05 - mse: 3.9380e-05 - val_loss: 3.4769e-05 - val_mse: 3.4769e-05 - 659ms/epoch - 5ms/step
# Epoch 122/150
# 126/126 - 1s - loss: 3.3992e-05 - mse: 3.3992e-05 - val_loss: 3.1429e-05 - val_mse: 3.1429e-05 - 665ms/epoch - 5ms/step
# Epoch 123/150
# 126/126 - 1s - loss: 3.5737e-05 - mse: 3.5737e-05 - val_loss: 7.2417e-05 - val_mse: 7.2417e-05 - 706ms/epoch - 6ms/step
# Epoch 124/150
# 126/126 - 1s - loss: 2.8686e-05 - mse: 2.8686e-05 - val_loss: 2.8914e-05 - val_mse: 2.8914e-05 - 794ms/epoch - 6ms/step
# Epoch 125/150
# 126/126 - 1s - loss: 3.0073e-05 - mse: 3.0073e-05 - val_loss: 3.0637e-05 - val_mse: 3.0637e-05 - 641ms/epoch - 5ms/step
# Epoch 126/150
# 126/126 - 1s - loss: 3.9180e-05 - mse: 3.9180e-05 - val_loss: 3.2823e-05 - val_mse: 3.2823e-05 - 785ms/epoch - 6ms/step
# Epoch 127/150
# 126/126 - 1s - loss: 3.0094e-05 - mse: 3.0094e-05 - val_loss: 3.5535e-05 - val_mse: 3.5535e-05 - 750ms/epoch - 6ms/step
# Epoch 128/150
# 126/126 - 1s - loss: 3.6347e-05 - mse: 3.6347e-05 - val_loss: 5.0084e-05 - val_mse: 5.0084e-05 - 669ms/epoch - 5ms/step
# Epoch 129/150
# 126/126 - 1s - loss: 3.0090e-05 - mse: 3.0090e-05 - val_loss: 3.0809e-05 - val_mse: 3.0809e-05 - 713ms/epoch - 6ms/step
# Epoch 130/150
# 126/126 - 1s - loss: 2.9925e-05 - mse: 2.9925e-05 - val_loss: 3.4510e-05 - val_mse: 3.4510e-05 - 675ms/epoch - 5ms/step
# Epoch 131/150
# 126/126 - 1s - loss: 3.3700e-05 - mse: 3.3700e-05 - val_loss: 3.2180e-05 - val_mse: 3.2179e-05 - 832ms/epoch - 7ms/step
# Epoch 132/150
# 126/126 - 1s - loss: 2.9278e-05 - mse: 2.9278e-05 - val_loss: 3.5042e-05 - val_mse: 3.5042e-05 - 703ms/epoch - 6ms/step
# Epoch 133/150
# 126/126 - 1s - loss: 3.0110e-05 - mse: 3.0110e-05 - val_loss: 2.5309e-05 - val_mse: 2.5309e-05 - 751ms/epoch - 6ms/step
# Epoch 134/150
# 126/126 - 1s - loss: 3.7958e-05 - mse: 3.7958e-05 - val_loss: 2.6615e-05 - val_mse: 2.6615e-05 - 690ms/epoch - 5ms/step
# Epoch 135/150
# 126/126 - 1s - loss: 3.0302e-05 - mse: 3.0302e-05 - val_loss: 8.8226e-05 - val_mse: 8.8226e-05 - 696ms/epoch - 6ms/step
# Epoch 136/150
# 126/126 - 1s - loss: 2.8334e-05 - mse: 2.8334e-05 - val_loss: 2.1872e-05 - val_mse: 2.1872e-05 - 736ms/epoch - 6ms/step
# Epoch 137/150
# 126/126 - 1s - loss: 3.0589e-05 - mse: 3.0589e-05 - val_loss: 2.4218e-05 - val_mse: 2.4218e-05 - 752ms/epoch - 6ms/step
# Epoch 138/150
# 126/126 - 1s - loss: 2.6180e-05 - mse: 2.6180e-05 - val_loss: 2.1300e-05 - val_mse: 2.1300e-05 - 768ms/epoch - 6ms/step
# Epoch 139/150
# 126/126 - 1s - loss: 3.5522e-05 - mse: 3.5522e-05 - val_loss: 2.4302e-05 - val_mse: 2.4302e-05 - 728ms/epoch - 6ms/step
# Epoch 140/150
# 126/126 - 1s - loss: 2.2971e-05 - mse: 2.2971e-05 - val_loss: 2.6955e-05 - val_mse: 2.6955e-05 - 853ms/epoch - 7ms/step
# Epoch 141/150
# 126/126 - 1s - loss: 2.9913e-05 - mse: 2.9913e-05 - val_loss: 2.6907e-05 - val_mse: 2.6907e-05 - 729ms/epoch - 6ms/step
# Epoch 142/150
# 126/126 - 1s - loss: 3.2825e-05 - mse: 3.2825e-05 - val_loss: 1.0066e-04 - val_mse: 1.0066e-04 - 726ms/epoch - 6ms/step
# Epoch 143/150
# 126/126 - 1s - loss: 2.7311e-05 - mse: 2.7311e-05 - val_loss: 8.6556e-05 - val_mse: 8.6556e-05 - 707ms/epoch - 6ms/step
# Epoch 144/150
# 126/126 - 1s - loss: 3.2450e-05 - mse: 3.2450e-05 - val_loss: 2.2818e-05 - val_mse: 2.2818e-05 - 783ms/epoch - 6ms/step
# Epoch 145/150
# 126/126 - 1s - loss: 2.4672e-05 - mse: 2.4672e-05 - val_loss: 1.9481e-05 - val_mse: 1.9481e-05 - 732ms/epoch - 6ms/step
# Epoch 146/150
# 126/126 - 1s - loss: 3.9662e-05 - mse: 3.9662e-05 - val_loss: 3.6678e-05 - val_mse: 3.6678e-05 - 725ms/epoch - 6ms/step
# Epoch 147/150
# 126/126 - 1s - loss: 2.9301e-05 - mse: 2.9301e-05 - val_loss: 1.9308e-05 - val_mse: 1.9308e-05 - 677ms/epoch - 5ms/step
# Epoch 148/150
# 126/126 - 1s - loss: 2.3102e-05 - mse: 2.3102e-05 - val_loss: 2.2358e-05 - val_mse: 2.2358e-05 - 698ms/epoch - 6ms/step
# Epoch 149/150
# 126/126 - 1s - loss: 2.6984e-05 - mse: 2.6984e-05 - val_loss: 3.2717e-05 - val_mse: 3.2717e-05 - 704ms/epoch - 6ms/step
# Epoch 150/150
# 126/126 - 1s - loss: 2.5504e-05 - mse: 2.5504e-05 - val_loss: 1.8741e-05 - val_mse: 1.8741e-05 - 690ms/epoch - 5ms/step

# %%
#use the test data to evaluate the model
loss_and_metrics = model1.evaluate(X_test, y_test, batch_size=256)
print(loss_and_metrics)

print(t1-t0)
model1.save('basic.h5') # save the pre-trained model as basic
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 1.8343e-05 - mse: 1.8343e-05
# [1.8342770999879576e-05, 1.834277281886898e-05]
# 111.89291024208069
