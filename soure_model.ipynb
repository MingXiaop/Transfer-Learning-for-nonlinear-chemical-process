# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, SimpleRNN, Input, Activation, Dropout
from keras import backend as K
from tensorflow.keras.optimizers import Adam,SGD
import tensorflow as tf
from keras.models import Model
from keras.models import load_model
import time #to calculate the computation time
# Out:
# 2022-10-13 01:36:22.539345: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-13 01:36:22.539424: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# specifying constant parameters
#input varioable: Q, C_A0
#state variable: T, C_A

T_0 = 300
V = 1
k_0 = 8.46*(np.power(10,6))
C_p = 0.231
rho_L = 1000
F = 5
E = 5*(np.power(10,4))
delta_H = -1.15*(np.power(10,4))
R = 8.314



T_0 += 0.1 * T_0
V += 0.1 * V
k_0 += 0.1 * k_0
C_p += 0.1 * C_p
rho_L += 0.1 * rho_L
F += 0.1 * F
E += 0.1 * E
delta_H += 0.1 * delta_H
R = R    #constant
  
Q_s = 0.0  # the steady state for input variable Q
C_A0s = 4.2   # the steady state for input variable C_A0

#calculated by let dCA/dt,dT/dt =0, via scipy
T_s = 333.47  #151997  # the steady state for state variable T
C_As = 4.12  #32945  # the steady state for state variable C_A

t_final = 0.01  #the control period
t_step = 1e-4   # the step to use first-principle to calculate the state
P = np.array([[1060, 22], [22, 0.52]])

# %%
#The data size for new-cstr should be consensus with the basic-one
# generating inputs and initial states for CSTR, all expressed in deviation form

# Test 1 full stability region
u1_list = np.linspace(-3.5, 3.5, 30, endpoint=True)
u2_list = np.linspace(-5e5, 5e5, 30, endpoint=True)
T_initial = np.linspace(200, 550, 30, endpoint=True) - T_s
CA_initial = np.linspace(0, 8., 30, endpoint=True) - C_As
#print(T_initial)
#control variable: C_A0, Q
#state variable: C_A, T

# sieve out initial states that lie outside of stability region

T_start = list()
CA_start = list()

for T in T_initial:   
    for CA in CA_initial:
        x = np.array([CA, T])
        if x @ P @ x < 480:   #calculate the stability region for state 
            CA_start.append(CA)
            T_start.append(T)
print("number of initial conditions: {}".format(len(CA_start)))

# convert to np.arrays
CA_start = np.array([CA_start])
T_start = np.array([T_start])
print(CA_start.shape)
x_deviation = np.concatenate((CA_start.T, T_start.T), axis=1)  # every row is a pair of initial states within stability region
print("shape of x_deviation is {}".format(x_deviation.shape))
print(x_deviation.shape)  # the initial state is in
# Out:
# number of initial conditions: 56
# (1, 56)
# shape of x_deviation is (56, 2)
# (56, 2)

# %%
def CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial):
    """
        simulating CSTR using forward Euler method
    """
    
    C_A_list = list()  # evolution of CA over time
    T_list = list()  # evolution of T over time
    
    C_A = C_A_initial + C_As  # the real state.the derivation plus the steady state
    T = T_initial + T_s
    
    for i in range(int(t_final / t_step)):
        dCAdt = F / V * (C_A0 - C_A) - k_0 * np.exp(-E / (R * T)) * C_A**2
        dTdt = F / V * (T_0 - T) - delta_H / (rho_L * C_p) * k_0 * np.exp(-E / (R * T)) * C_A**2 + Q / (rho_L * C_p * V)
        
        C_A += dCAdt * t_step
        T += dTdt * t_step
        
        if i%5 ==0:
            C_A_list.append(C_A - C_As)  # in deviation form
            T_list.append(T - T_s)  # in deviation form 
    
    return C_A_list, T_list

# %%
# get X and y data for training and testing

CA_output = list()
T_output = list()

CA_input = list()
T_input = list()
CA0_input = list()
Q_input = list()   #input variable for 

for u1 in u1_list:
    C_A0 = u1 + C_A0s
    
    for u2 in u2_list:
        Q = u2 + Q_s
        
        for C_A_initial, T_initial in x_deviation:
            CA0_input.append(u1)
            Q_input.append(u2)
            CA_input.append(C_A_initial)
            T_input.append(T_initial)
            
            C_A_list, T_list = CSTR_simulation(F, V, C_A0, k_0, E, R, T_0, delta_H, rho_L, C_p, Q, t_final, t_step, C_A_initial, T_initial)
            CA_output.append(C_A_list)
            T_output.append(T_list)

# %%
# collate input for RNN

CA0_input = np.array(CA0_input)
CA0_input = CA0_input.reshape(-1,1,1)

Q_input = np.array(Q_input)
Q_input = Q_input.reshape(-1,1,1)

CA_input = np.array(CA_input)
CA_input = CA_input.reshape(-1,1,1)

T_input = np.array(T_input)
T_input = T_input.reshape(-1,1,1)

RNN_input = np.concatenate((T_input, CA_input, Q_input, CA0_input), axis=2)   #the value for input variable and the initial value for state variable 

"""
    the input to RNN is in the shape [number of samples x timestep x variables], and the input variables are same for every
    time step, not sure if my treatment here is correct
"""
print("RNN_input shape is {}".format(RNN_input.shape))
RNN_input = RNN_input.repeat(20, axis=1)  # to keep consensus with the shape for RNN_output, since the output variable is collected 100(0.01/1e-4) times for each RNN_input
print("RNN_input shape is {}".format(RNN_input.shape))
# Out:
# RNN_input shape is (50400, 1, 4)
# RNN_input shape is (50400, 20, 4)

# %%
# collate output for RNN

CA_output = np.array(CA_output)
CA_output = CA_output.reshape(-1, 20, 1)

T_output = np.array(T_output)
T_output = T_output.reshape(-1, 20, 1)

RNN_output = np.concatenate((T_output, CA_output), axis=2)
print("RNN_output shape is {}".format(RNN_output.shape))  # output shape: number of samples x timestep x variables
# Out:
# RNN_output shape is (50400, 20, 2)

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(RNN_input, RNN_output, test_size=0.15, random_state=123)

# define scalers for both X and y base on training data only
scaler_X = preprocessing.StandardScaler().fit(X_train.reshape(-1, 4))
scaler_y = preprocessing.StandardScaler().fit(y_train.reshape(-1, 2))


X_train = scaler_X.transform(X_train.reshape(-1, 4)).reshape(-1,20,4)
X_test = scaler_X.transform(X_test.reshape(-1, 4)).reshape(-1,20,4)
y_train = scaler_y.transform(y_train.reshape(-1,2)).reshape(-1,20,2)
y_test = scaler_y.transform(y_test.reshape(-1,2)).reshape(-1,20,2)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (42840, 20, 4) (7560, 20, 4) (42840, 20, 2) (7560, 20, 2)

# %%
model1 = Sequential()
model1.add(SimpleRNN(32, activation='tanh', return_sequences=True))
model1.add(Dense(2, activation='linear'))
model1.compile(optimizer='adam', loss='mse', metrics=['mse'])

t0 = time.time()
history = model1.fit(X_train, y_train, epochs=150, batch_size=256, validation_split=0.25, verbose=2)
t1 = time.time()
# Out:
# Epoch 1/150
# 2022-10-13 01:37:09.701128: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-10-13 01:37:09.701170: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-13 01:37:09.701190: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c895b2a47570): /proc/driver/nvidia/version does not exist
# 2022-10-13 01:37:09.701372: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 126/126 - 2s - loss: 0.1794 - mse: 0.1794 - val_loss: 0.0420 - val_mse: 0.0420 - 2s/epoch - 14ms/step
# Epoch 2/150
# 126/126 - 1s - loss: 0.0242 - mse: 0.0242 - val_loss: 0.0148 - val_mse: 0.0148 - 734ms/epoch - 6ms/step
# Epoch 3/150
# 126/126 - 1s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0082 - val_mse: 0.0082 - 760ms/epoch - 6ms/step
# Epoch 4/150
# 126/126 - 1s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0057 - val_mse: 0.0057 - 827ms/epoch - 7ms/step
# Epoch 5/150
# 126/126 - 1s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0045 - val_mse: 0.0045 - 758ms/epoch - 6ms/step
# Epoch 6/150
# 126/126 - 1s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 799ms/epoch - 6ms/step
# Epoch 7/150
# 126/126 - 1s - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0032 - val_mse: 0.0032 - 720ms/epoch - 6ms/step
# Epoch 8/150
# 126/126 - 1s - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027 - 756ms/epoch - 6ms/step
# Epoch 9/150
# 126/126 - 1s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024 - 801ms/epoch - 6ms/step
# Epoch 10/150
# 126/126 - 1s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021 - 755ms/epoch - 6ms/step
# Epoch 11/150
# 126/126 - 1s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0018 - val_mse: 0.0018 - 792ms/epoch - 6ms/step
# Epoch 12/150
# 126/126 - 1s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 764ms/epoch - 6ms/step
# Epoch 13/150
# 126/126 - 1s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015 - 760ms/epoch - 6ms/step
# Epoch 14/150
# 126/126 - 1s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 813ms/epoch - 6ms/step
# Epoch 15/150
# 126/126 - 1s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 725ms/epoch - 6ms/step
# Epoch 16/150
# 126/126 - 1s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 755ms/epoch - 6ms/step
# Epoch 17/150
# 126/126 - 1s - loss: 9.9551e-04 - mse: 9.9551e-04 - val_loss: 9.7659e-04 - val_mse: 9.7659e-04 - 770ms/epoch - 6ms/step
# Epoch 18/150
# 126/126 - 1s - loss: 9.0305e-04 - mse: 9.0305e-04 - val_loss: 8.9072e-04 - val_mse: 8.9072e-04 - 799ms/epoch - 6ms/step
# Epoch 19/150
# 126/126 - 1s - loss: 8.2204e-04 - mse: 8.2204e-04 - val_loss: 8.0764e-04 - val_mse: 8.0764e-04 - 776ms/epoch - 6ms/step
# Epoch 20/150
# 126/126 - 1s - loss: 7.4746e-04 - mse: 7.4746e-04 - val_loss: 7.3720e-04 - val_mse: 7.3720e-04 - 760ms/epoch - 6ms/step
# Epoch 21/150
# 126/126 - 1s - loss: 6.8490e-04 - mse: 6.8490e-04 - val_loss: 6.7602e-04 - val_mse: 6.7602e-04 - 756ms/epoch - 6ms/step
# Epoch 22/150
# 126/126 - 1s - loss: 6.3211e-04 - mse: 6.3211e-04 - val_loss: 6.2449e-04 - val_mse: 6.2449e-04 - 793ms/epoch - 6ms/step
# Epoch 23/150
# 126/126 - 1s - loss: 5.7711e-04 - mse: 5.7711e-04 - val_loss: 5.8138e-04 - val_mse: 5.8138e-04 - 815ms/epoch - 6ms/step
# Epoch 24/150
# 126/126 - 1s - loss: 5.3312e-04 - mse: 5.3312e-04 - val_loss: 5.2655e-04 - val_mse: 5.2655e-04 - 772ms/epoch - 6ms/step
# Epoch 25/150
# 126/126 - 1s - loss: 4.9369e-04 - mse: 4.9369e-04 - val_loss: 4.8251e-04 - val_mse: 4.8251e-04 - 809ms/epoch - 6ms/step
# Epoch 26/150
# 126/126 - 1s - loss: 4.5284e-04 - mse: 4.5284e-04 - val_loss: 4.5694e-04 - val_mse: 4.5694e-04 - 786ms/epoch - 6ms/step
# Epoch 27/150
# 126/126 - 1s - loss: 4.2009e-04 - mse: 4.2009e-04 - val_loss: 4.9143e-04 - val_mse: 4.9143e-04 - 795ms/epoch - 6ms/step
# Epoch 28/150
# 126/126 - 1s - loss: 3.9483e-04 - mse: 3.9483e-04 - val_loss: 3.9308e-04 - val_mse: 3.9308e-04 - 716ms/epoch - 6ms/step
# Epoch 29/150
# 126/126 - 1s - loss: 3.7321e-04 - mse: 3.7321e-04 - val_loss: 3.8186e-04 - val_mse: 3.8186e-04 - 758ms/epoch - 6ms/step
# Epoch 30/150
# 126/126 - 1s - loss: 3.4263e-04 - mse: 3.4263e-04 - val_loss: 3.4674e-04 - val_mse: 3.4674e-04 - 845ms/epoch - 7ms/step
# Epoch 31/150
# 126/126 - 1s - loss: 3.1871e-04 - mse: 3.1871e-04 - val_loss: 3.3168e-04 - val_mse: 3.3168e-04 - 887ms/epoch - 7ms/step
# Epoch 32/150
# 126/126 - 1s - loss: 2.9662e-04 - mse: 2.9662e-04 - val_loss: 2.9841e-04 - val_mse: 2.9841e-04 - 751ms/epoch - 6ms/step
# Epoch 33/150
# 126/126 - 1s - loss: 2.9525e-04 - mse: 2.9525e-04 - val_loss: 3.3261e-04 - val_mse: 3.3261e-04 - 739ms/epoch - 6ms/step
# Epoch 34/150
# 126/126 - 1s - loss: 2.7090e-04 - mse: 2.7090e-04 - val_loss: 2.6910e-04 - val_mse: 2.6910e-04 - 759ms/epoch - 6ms/step
# Epoch 35/150
# 126/126 - 1s - loss: 2.5016e-04 - mse: 2.5016e-04 - val_loss: 2.5181e-04 - val_mse: 2.5181e-04 - 792ms/epoch - 6ms/step
# Epoch 36/150
# 126/126 - 1s - loss: 2.4462e-04 - mse: 2.4462e-04 - val_loss: 2.4505e-04 - val_mse: 2.4505e-04 - 808ms/epoch - 6ms/step
# Epoch 37/150
# 126/126 - 1s - loss: 2.2166e-04 - mse: 2.2166e-04 - val_loss: 2.1588e-04 - val_mse: 2.1588e-04 - 758ms/epoch - 6ms/step
# Epoch 38/150
# 126/126 - 1s - loss: 2.1550e-04 - mse: 2.1550e-04 - val_loss: 2.1246e-04 - val_mse: 2.1246e-04 - 775ms/epoch - 6ms/step
# Epoch 39/150
# 126/126 - 1s - loss: 2.0489e-04 - mse: 2.0489e-04 - val_loss: 2.0211e-04 - val_mse: 2.0211e-04 - 794ms/epoch - 6ms/step
# Epoch 40/150
# 126/126 - 1s - loss: 1.8460e-04 - mse: 1.8460e-04 - val_loss: 1.8551e-04 - val_mse: 1.8551e-04 - 773ms/epoch - 6ms/step
# Epoch 41/150
# 126/126 - 1s - loss: 1.8290e-04 - mse: 1.8290e-04 - val_loss: 2.0366e-04 - val_mse: 2.0366e-04 - 718ms/epoch - 6ms/step
# Epoch 42/150
# 126/126 - 1s - loss: 1.7099e-04 - mse: 1.7099e-04 - val_loss: 1.7072e-04 - val_mse: 1.7072e-04 - 790ms/epoch - 6ms/step
# Epoch 43/150
# 126/126 - 1s - loss: 1.6611e-04 - mse: 1.6611e-04 - val_loss: 1.7170e-04 - val_mse: 1.7170e-04 - 806ms/epoch - 6ms/step
# Epoch 44/150
# 126/126 - 1s - loss: 1.6401e-04 - mse: 1.6401e-04 - val_loss: 1.5042e-04 - val_mse: 1.5042e-04 - 838ms/epoch - 7ms/step
# Epoch 45/150
# 126/126 - 1s - loss: 1.5362e-04 - mse: 1.5362e-04 - val_loss: 1.4846e-04 - val_mse: 1.4846e-04 - 742ms/epoch - 6ms/step
# Epoch 46/150
# 126/126 - 1s - loss: 1.4026e-04 - mse: 1.4026e-04 - val_loss: 1.5210e-04 - val_mse: 1.5210e-04 - 735ms/epoch - 6ms/step
# Epoch 47/150
# 126/126 - 1s - loss: 1.3671e-04 - mse: 1.3671e-04 - val_loss: 1.2967e-04 - val_mse: 1.2967e-04 - 756ms/epoch - 6ms/step
# Epoch 48/150
# 126/126 - 1s - loss: 1.3871e-04 - mse: 1.3871e-04 - val_loss: 1.2432e-04 - val_mse: 1.2432e-04 - 828ms/epoch - 7ms/step
# Epoch 49/150
# 126/126 - 1s - loss: 1.2601e-04 - mse: 1.2601e-04 - val_loss: 1.2406e-04 - val_mse: 1.2406e-04 - 772ms/epoch - 6ms/step
# Epoch 50/150
# 126/126 - 1s - loss: 1.1642e-04 - mse: 1.1642e-04 - val_loss: 1.1803e-04 - val_mse: 1.1803e-04 - 776ms/epoch - 6ms/step
# Epoch 51/150
# 126/126 - 1s - loss: 1.2316e-04 - mse: 1.2316e-04 - val_loss: 1.0817e-04 - val_mse: 1.0817e-04 - 759ms/epoch - 6ms/step
# Epoch 52/150
# 126/126 - 1s - loss: 1.1581e-04 - mse: 1.1581e-04 - val_loss: 1.1674e-04 - val_mse: 1.1674e-04 - 803ms/epoch - 6ms/step
# Epoch 53/150
# 126/126 - 1s - loss: 1.0884e-04 - mse: 1.0884e-04 - val_loss: 1.0335e-04 - val_mse: 1.0335e-04 - 774ms/epoch - 6ms/step
# Epoch 54/150
# 126/126 - 1s - loss: 1.0125e-04 - mse: 1.0125e-04 - val_loss: 9.9687e-05 - val_mse: 9.9687e-05 - 722ms/epoch - 6ms/step
# Epoch 55/150
# 126/126 - 1s - loss: 1.1154e-04 - mse: 1.1154e-04 - val_loss: 9.4864e-05 - val_mse: 9.4864e-05 - 819ms/epoch - 6ms/step
# Epoch 56/150
# 126/126 - 1s - loss: 9.9426e-05 - mse: 9.9426e-05 - val_loss: 9.8062e-05 - val_mse: 9.8062e-05 - 815ms/epoch - 6ms/step
# Epoch 57/150
# 126/126 - 1s - loss: 9.7923e-05 - mse: 9.7923e-05 - val_loss: 9.2689e-05 - val_mse: 9.2689e-05 - 825ms/epoch - 7ms/step
# Epoch 58/150
# 126/126 - 1s - loss: 9.1093e-05 - mse: 9.1093e-05 - val_loss: 1.9395e-04 - val_mse: 1.9395e-04 - 749ms/epoch - 6ms/step
# Epoch 59/150
# 126/126 - 1s - loss: 8.8288e-05 - mse: 8.8288e-05 - val_loss: 8.3460e-05 - val_mse: 8.3460e-05 - 732ms/epoch - 6ms/step
# Epoch 60/150
# 126/126 - 1s - loss: 8.4507e-05 - mse: 8.4507e-05 - val_loss: 1.1053e-04 - val_mse: 1.1053e-04 - 750ms/epoch - 6ms/step
# Epoch 61/150
# 126/126 - 1s - loss: 8.4843e-05 - mse: 8.4843e-05 - val_loss: 9.3744e-05 - val_mse: 9.3744e-05 - 830ms/epoch - 7ms/step
# Epoch 62/150
# 126/126 - 1s - loss: 8.0466e-05 - mse: 8.0466e-05 - val_loss: 1.0701e-04 - val_mse: 1.0701e-04 - 775ms/epoch - 6ms/step
# Epoch 63/150
# 126/126 - 1s - loss: 9.7008e-05 - mse: 9.7008e-05 - val_loss: 7.9982e-05 - val_mse: 7.9982e-05 - 793ms/epoch - 6ms/step
# Epoch 64/150
# 126/126 - 1s - loss: 7.1959e-05 - mse: 7.1959e-05 - val_loss: 8.5854e-05 - val_mse: 8.5854e-05 - 764ms/epoch - 6ms/step
# Epoch 65/150
# 126/126 - 1s - loss: 7.1409e-05 - mse: 7.1409e-05 - val_loss: 8.2612e-05 - val_mse: 8.2612e-05 - 778ms/epoch - 6ms/step
# Epoch 66/150
# 126/126 - 1s - loss: 7.8109e-05 - mse: 7.8109e-05 - val_loss: 7.5224e-05 - val_mse: 7.5224e-05 - 772ms/epoch - 6ms/step
# Epoch 67/150
# 126/126 - 1s - loss: 6.9334e-05 - mse: 6.9334e-05 - val_loss: 7.5524e-05 - val_mse: 7.5524e-05 - 722ms/epoch - 6ms/step
# Epoch 68/150
# 126/126 - 1s - loss: 6.9988e-05 - mse: 6.9988e-05 - val_loss: 6.4663e-05 - val_mse: 6.4663e-05 - 835ms/epoch - 7ms/step
# Epoch 69/150
# 126/126 - 1s - loss: 6.8649e-05 - mse: 6.8649e-05 - val_loss: 6.3535e-05 - val_mse: 6.3535e-05 - 793ms/epoch - 6ms/step
# Epoch 70/150
# 126/126 - 1s - loss: 6.7834e-05 - mse: 6.7834e-05 - val_loss: 6.1165e-05 - val_mse: 6.1165e-05 - 802ms/epoch - 6ms/step
# Epoch 71/150
# 126/126 - 1s - loss: 6.6894e-05 - mse: 6.6894e-05 - val_loss: 5.6543e-05 - val_mse: 5.6543e-05 - 748ms/epoch - 6ms/step
# Epoch 72/150
# 126/126 - 1s - loss: 6.8753e-05 - mse: 6.8753e-05 - val_loss: 6.6734e-05 - val_mse: 6.6734e-05 - 730ms/epoch - 6ms/step
# Epoch 73/150
# 126/126 - 1s - loss: 6.1639e-05 - mse: 6.1639e-05 - val_loss: 5.6484e-05 - val_mse: 5.6484e-05 - 799ms/epoch - 6ms/step
# Epoch 74/150
# 126/126 - 1s - loss: 5.8304e-05 - mse: 5.8304e-05 - val_loss: 6.3798e-05 - val_mse: 6.3798e-05 - 953ms/epoch - 8ms/step
# Epoch 75/150
# 126/126 - 1s - loss: 6.1502e-05 - mse: 6.1502e-05 - val_loss: 7.2082e-05 - val_mse: 7.2082e-05 - 765ms/epoch - 6ms/step
# Epoch 76/150
# 126/126 - 1s - loss: 5.2550e-05 - mse: 5.2550e-05 - val_loss: 6.8385e-05 - val_mse: 6.8385e-05 - 895ms/epoch - 7ms/step
# Epoch 77/150
# 126/126 - 1s - loss: 5.3535e-05 - mse: 5.3535e-05 - val_loss: 5.2542e-05 - val_mse: 5.2542e-05 - 896ms/epoch - 7ms/step
# Epoch 78/150
# 126/126 - 1s - loss: 7.7347e-05 - mse: 7.7347e-05 - val_loss: 5.2825e-05 - val_mse: 5.2825e-05 - 998ms/epoch - 8ms/step
# Epoch 79/150
# 126/126 - 1s - loss: 4.7681e-05 - mse: 4.7681e-05 - val_loss: 5.1549e-05 - val_mse: 5.1549e-05 - 806ms/epoch - 6ms/step
# Epoch 80/150
# 126/126 - 1s - loss: 5.1488e-05 - mse: 5.1488e-05 - val_loss: 7.7662e-05 - val_mse: 7.7663e-05 - 867ms/epoch - 7ms/step
# Epoch 81/150
# 126/126 - 1s - loss: 5.5267e-05 - mse: 5.5267e-05 - val_loss: 4.8850e-05 - val_mse: 4.8850e-05 - 784ms/epoch - 6ms/step
# Epoch 82/150
# 126/126 - 1s - loss: 5.0126e-05 - mse: 5.0126e-05 - val_loss: 5.9123e-05 - val_mse: 5.9123e-05 - 885ms/epoch - 7ms/step
# Epoch 83/150
# 126/126 - 1s - loss: 6.2135e-05 - mse: 6.2135e-05 - val_loss: 5.1222e-05 - val_mse: 5.1222e-05 - 861ms/epoch - 7ms/step
# Epoch 84/150
# 126/126 - 1s - loss: 4.8081e-05 - mse: 4.8081e-05 - val_loss: 6.3252e-05 - val_mse: 6.3252e-05 - 883ms/epoch - 7ms/step
# Epoch 85/150
# 126/126 - 1s - loss: 4.6688e-05 - mse: 4.6688e-05 - val_loss: 5.3795e-05 - val_mse: 5.3795e-05 - 901ms/epoch - 7ms/step
# Epoch 86/150
# 126/126 - 1s - loss: 6.2657e-05 - mse: 6.2657e-05 - val_loss: 4.4278e-05 - val_mse: 4.4278e-05 - 1s/epoch - 8ms/step
# Epoch 87/150
# 126/126 - 1s - loss: 4.2114e-05 - mse: 4.2114e-05 - val_loss: 4.0586e-05 - val_mse: 4.0586e-05 - 912ms/epoch - 7ms/step
# Epoch 88/150
# 126/126 - 1s - loss: 4.3912e-05 - mse: 4.3912e-05 - val_loss: 4.5478e-05 - val_mse: 4.5478e-05 - 896ms/epoch - 7ms/step
# Epoch 89/150
# 126/126 - 1s - loss: 4.3372e-05 - mse: 4.3372e-05 - val_loss: 4.6528e-05 - val_mse: 4.6528e-05 - 917ms/epoch - 7ms/step
# Epoch 90/150
# 126/126 - 1s - loss: 4.9633e-05 - mse: 4.9633e-05 - val_loss: 4.5149e-05 - val_mse: 4.5149e-05 - 824ms/epoch - 7ms/step
# Epoch 91/150
# 126/126 - 1s - loss: 4.1191e-05 - mse: 4.1191e-05 - val_loss: 4.0994e-05 - val_mse: 4.0994e-05 - 882ms/epoch - 7ms/step
# Epoch 92/150
# 126/126 - 1s - loss: 4.5731e-05 - mse: 4.5731e-05 - val_loss: 5.4041e-05 - val_mse: 5.4041e-05 - 872ms/epoch - 7ms/step
# Epoch 93/150
# 126/126 - 1s - loss: 4.1307e-05 - mse: 4.1307e-05 - val_loss: 5.1388e-05 - val_mse: 5.1388e-05 - 813ms/epoch - 6ms/step
# Epoch 94/150
# 126/126 - 1s - loss: 4.3804e-05 - mse: 4.3804e-05 - val_loss: 5.6895e-05 - val_mse: 5.6895e-05 - 765ms/epoch - 6ms/step
# Epoch 95/150
# 126/126 - 1s - loss: 3.7016e-05 - mse: 3.7016e-05 - val_loss: 3.3988e-05 - val_mse: 3.3988e-05 - 743ms/epoch - 6ms/step
# Epoch 96/150
# 126/126 - 1s - loss: 4.5777e-05 - mse: 4.5777e-05 - val_loss: 3.7312e-05 - val_mse: 3.7312e-05 - 764ms/epoch - 6ms/step
# Epoch 97/150
# 126/126 - 1s - loss: 3.5521e-05 - mse: 3.5521e-05 - val_loss: 8.6771e-05 - val_mse: 8.6771e-05 - 756ms/epoch - 6ms/step
# Epoch 98/150
# 126/126 - 1s - loss: 4.2867e-05 - mse: 4.2867e-05 - val_loss: 3.4266e-05 - val_mse: 3.4266e-05 - 835ms/epoch - 7ms/step
# Epoch 99/150
# 126/126 - 1s - loss: 4.0919e-05 - mse: 4.0919e-05 - val_loss: 4.5753e-05 - val_mse: 4.5753e-05 - 785ms/epoch - 6ms/step
# Epoch 100/150
# 126/126 - 1s - loss: 3.5810e-05 - mse: 3.5810e-05 - val_loss: 4.7465e-05 - val_mse: 4.7465e-05 - 807ms/epoch - 6ms/step
# Epoch 101/150
# 126/126 - 1s - loss: 3.9773e-05 - mse: 3.9773e-05 - val_loss: 3.7057e-05 - val_mse: 3.7057e-05 - 723ms/epoch - 6ms/step
# Epoch 102/150
# 126/126 - 1s - loss: 4.4545e-05 - mse: 4.4545e-05 - val_loss: 3.4350e-05 - val_mse: 3.4350e-05 - 836ms/epoch - 7ms/step
# Epoch 103/150
# 126/126 - 1s - loss: 3.3125e-05 - mse: 3.3125e-05 - val_loss: 4.6504e-05 - val_mse: 4.6504e-05 - 721ms/epoch - 6ms/step
# Epoch 104/150
# 126/126 - 1s - loss: 3.6286e-05 - mse: 3.6286e-05 - val_loss: 7.9088e-05 - val_mse: 7.9088e-05 - 874ms/epoch - 7ms/step
# Epoch 105/150
# 126/126 - 1s - loss: 3.5391e-05 - mse: 3.5391e-05 - val_loss: 2.9012e-05 - val_mse: 2.9012e-05 - 827ms/epoch - 7ms/step
# Epoch 106/150
# 126/126 - 1s - loss: 4.0290e-05 - mse: 4.0290e-05 - val_loss: 4.8223e-05 - val_mse: 4.8223e-05 - 798ms/epoch - 6ms/step
# Epoch 107/150
# 126/126 - 1s - loss: 3.7481e-05 - mse: 3.7481e-05 - val_loss: 4.3366e-05 - val_mse: 4.3366e-05 - 760ms/epoch - 6ms/step
# Epoch 108/150
# 126/126 - 1s - loss: 3.5187e-05 - mse: 3.5187e-05 - val_loss: 4.0013e-05 - val_mse: 4.0013e-05 - 789ms/epoch - 6ms/step
# Epoch 109/150
# 126/126 - 1s - loss: 3.7235e-05 - mse: 3.7235e-05 - val_loss: 3.2138e-05 - val_mse: 3.2138e-05 - 735ms/epoch - 6ms/step
# Epoch 110/150
# 126/126 - 1s - loss: 3.0753e-05 - mse: 3.0753e-05 - val_loss: 2.8576e-05 - val_mse: 2.8576e-05 - 861ms/epoch - 7ms/step
# Epoch 111/150
# 126/126 - 1s - loss: 3.6545e-05 - mse: 3.6545e-05 - val_loss: 2.8824e-05 - val_mse: 2.8824e-05 - 752ms/epoch - 6ms/step
# Epoch 112/150
# 126/126 - 1s - loss: 3.2991e-05 - mse: 3.2991e-05 - val_loss: 2.9646e-05 - val_mse: 2.9646e-05 - 835ms/epoch - 7ms/step
# Epoch 113/150
# 126/126 - 1s - loss: 3.3153e-05 - mse: 3.3153e-05 - val_loss: 3.0352e-05 - val_mse: 3.0352e-05 - 765ms/epoch - 6ms/step
# Epoch 114/150
# 126/126 - 1s - loss: 3.4140e-05 - mse: 3.4140e-05 - val_loss: 4.1988e-05 - val_mse: 4.1988e-05 - 741ms/epoch - 6ms/step
# Epoch 115/150
# 126/126 - 1s - loss: 3.4605e-05 - mse: 3.4605e-05 - val_loss: 2.5040e-05 - val_mse: 2.5040e-05 - 854ms/epoch - 7ms/step
# Epoch 116/150
# 126/126 - 1s - loss: 2.9334e-05 - mse: 2.9334e-05 - val_loss: 5.8468e-05 - val_mse: 5.8468e-05 - 760ms/epoch - 6ms/step
# Epoch 117/150
# 126/126 - 1s - loss: 3.2055e-05 - mse: 3.2055e-05 - val_loss: 3.0851e-05 - val_mse: 3.0851e-05 - 838ms/epoch - 7ms/step
# Epoch 118/150
# 126/126 - 1s - loss: 3.2349e-05 - mse: 3.2349e-05 - val_loss: 2.8237e-05 - val_mse: 2.8237e-05 - 823ms/epoch - 7ms/step
# Epoch 119/150
# 126/126 - 1s - loss: 3.3099e-05 - mse: 3.3099e-05 - val_loss: 9.0637e-05 - val_mse: 9.0637e-05 - 811ms/epoch - 6ms/step
# Epoch 120/150
# 126/126 - 1s - loss: 3.3386e-05 - mse: 3.3386e-05 - val_loss: 2.4819e-05 - val_mse: 2.4819e-05 - 854ms/epoch - 7ms/step
# Epoch 121/150
# 126/126 - 1s - loss: 2.7365e-05 - mse: 2.7365e-05 - val_loss: 2.6336e-05 - val_mse: 2.6336e-05 - 792ms/epoch - 6ms/step
# Epoch 122/150
# 126/126 - 1s - loss: 3.2361e-05 - mse: 3.2361e-05 - val_loss: 2.3146e-05 - val_mse: 2.3146e-05 - 752ms/epoch - 6ms/step
# Epoch 123/150
# 126/126 - 1s - loss: 2.8655e-05 - mse: 2.8655e-05 - val_loss: 2.7154e-05 - val_mse: 2.7154e-05 - 999ms/epoch - 8ms/step
# Epoch 124/150
# 126/126 - 1s - loss: 3.0195e-05 - mse: 3.0195e-05 - val_loss: 2.8966e-05 - val_mse: 2.8966e-05 - 814ms/epoch - 6ms/step
# Epoch 125/150
# 126/126 - 1s - loss: 2.4998e-05 - mse: 2.4998e-05 - val_loss: 2.5358e-05 - val_mse: 2.5358e-05 - 755ms/epoch - 6ms/step
# Epoch 126/150
# 126/126 - 1s - loss: 3.6481e-05 - mse: 3.6481e-05 - val_loss: 2.2990e-05 - val_mse: 2.2990e-05 - 761ms/epoch - 6ms/step
# Epoch 127/150
# 126/126 - 1s - loss: 3.1641e-05 - mse: 3.1641e-05 - val_loss: 2.2779e-05 - val_mse: 2.2779e-05 - 835ms/epoch - 7ms/step
# Epoch 128/150
# 126/126 - 1s - loss: 2.3843e-05 - mse: 2.3843e-05 - val_loss: 3.4189e-05 - val_mse: 3.4189e-05 - 750ms/epoch - 6ms/step
# Epoch 129/150
# 126/126 - 1s - loss: 2.4321e-05 - mse: 2.4321e-05 - val_loss: 3.0286e-05 - val_mse: 3.0286e-05 - 832ms/epoch - 7ms/step
# Epoch 130/150
# 126/126 - 1s - loss: 3.0383e-05 - mse: 3.0383e-05 - val_loss: 2.0604e-05 - val_mse: 2.0604e-05 - 734ms/epoch - 6ms/step
# Epoch 131/150
# 126/126 - 1s - loss: 2.7610e-05 - mse: 2.7610e-05 - val_loss: 2.1226e-05 - val_mse: 2.1226e-05 - 802ms/epoch - 6ms/step
# Epoch 132/150
# 126/126 - 1s - loss: 2.5504e-05 - mse: 2.5504e-05 - val_loss: 2.7724e-05 - val_mse: 2.7724e-05 - 749ms/epoch - 6ms/step
# Epoch 133/150
# 126/126 - 1s - loss: 2.9193e-05 - mse: 2.9193e-05 - val_loss: 2.4073e-05 - val_mse: 2.4073e-05 - 748ms/epoch - 6ms/step
# Epoch 134/150
# 126/126 - 1s - loss: 2.5086e-05 - mse: 2.5086e-05 - val_loss: 3.3455e-05 - val_mse: 3.3455e-05 - 750ms/epoch - 6ms/step
# Epoch 135/150
# 126/126 - 1s - loss: 2.4699e-05 - mse: 2.4699e-05 - val_loss: 2.1954e-05 - val_mse: 2.1954e-05 - 795ms/epoch - 6ms/step
# Epoch 136/150
# 126/126 - 1s - loss: 2.5239e-05 - mse: 2.5239e-05 - val_loss: 2.4241e-05 - val_mse: 2.4241e-05 - 813ms/epoch - 6ms/step
# Epoch 137/150
# 126/126 - 1s - loss: 2.6834e-05 - mse: 2.6834e-05 - val_loss: 3.4905e-05 - val_mse: 3.4905e-05 - 835ms/epoch - 7ms/step
# Epoch 138/150
# 126/126 - 1s - loss: 2.7734e-05 - mse: 2.7734e-05 - val_loss: 2.5204e-05 - val_mse: 2.5204e-05 - 729ms/epoch - 6ms/step
# Epoch 139/150
# 126/126 - 1s - loss: 2.3871e-05 - mse: 2.3871e-05 - val_loss: 2.1424e-05 - val_mse: 2.1424e-05 - 760ms/epoch - 6ms/step
# Epoch 140/150
# 126/126 - 1s - loss: 2.3602e-05 - mse: 2.3602e-05 - val_loss: 4.3824e-05 - val_mse: 4.3824e-05 - 781ms/epoch - 6ms/step
# Epoch 141/150
# 126/126 - 1s - loss: 2.9687e-05 - mse: 2.9687e-05 - val_loss: 2.4171e-05 - val_mse: 2.4171e-05 - 791ms/epoch - 6ms/step
# Epoch 142/150
# 126/126 - 1s - loss: 2.1455e-05 - mse: 2.1455e-05 - val_loss: 1.8807e-05 - val_mse: 1.8807e-05 - 844ms/epoch - 7ms/step
# Epoch 143/150
# 126/126 - 1s - loss: 2.7701e-05 - mse: 2.7701e-05 - val_loss: 2.1008e-05 - val_mse: 2.1008e-05 - 777ms/epoch - 6ms/step
# Epoch 144/150
# 126/126 - 1s - loss: 2.1761e-05 - mse: 2.1761e-05 - val_loss: 1.9198e-05 - val_mse: 1.9198e-05 - 846ms/epoch - 7ms/step
# Epoch 145/150
# 126/126 - 1s - loss: 2.8354e-05 - mse: 2.8354e-05 - val_loss: 7.9654e-05 - val_mse: 7.9654e-05 - 802ms/epoch - 6ms/step
# Epoch 146/150
# 126/126 - 1s - loss: 2.8900e-05 - mse: 2.8900e-05 - val_loss: 1.8193e-05 - val_mse: 1.8193e-05 - 770ms/epoch - 6ms/step
# Epoch 147/150
# 126/126 - 1s - loss: 2.2147e-05 - mse: 2.2147e-05 - val_loss: 1.5804e-05 - val_mse: 1.5804e-05 - 777ms/epoch - 6ms/step
# Epoch 148/150
# 126/126 - 1s - loss: 2.1870e-05 - mse: 2.1870e-05 - val_loss: 2.0906e-05 - val_mse: 2.0906e-05 - 877ms/epoch - 7ms/step
# Epoch 149/150
# 126/126 - 1s - loss: 2.5583e-05 - mse: 2.5583e-05 - val_loss: 1.9397e-05 - val_mse: 1.9397e-05 - 828ms/epoch - 7ms/step
# Epoch 150/150
# 126/126 - 1s - loss: 2.1075e-05 - mse: 2.1075e-05 - val_loss: 2.2084e-05 - val_mse: 2.2084e-05 - 811ms/epoch - 6ms/step

# %%
#use the test data to evaluate the model
loss_and_metrics = model1.evaluate(X_test, y_test, batch_size=256)
print(loss_and_metrics)

print(t1-t0)
model1.save('basic.h5')
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1570e-05 - mse: 2.1570e-05
# [2.1569929231191054e-05, 2.1569925593212247e-05]
# 121.02355551719666
